# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinisenso/Multcriteria_Project/blob/main/Sele%C3%A7%C3%A3o_de_Interc%C3%A2mbios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Ranqueamento de intercambios da deri usando PROMETHEE**

# %% [markdown]
# **Como usar?**
#
# Passo 1: Rode a biblioteca.
#
# Passo 2: Informe os 4 tipos preferências.
#
# Passo 3: Rode a preferência.
#
# Passo 4: Rode o processamendo
#
# Pronto! Tudo certo!
#
# Se atente as mensagens que podem ser enviadas ao rodar o programa, elas vão te informar se tiver algo errado ou incompleto!

# %%
#@title Importando bibliotecas { display-mode: "form" }

# Bibliotecas
import math
import numpy as np
import pandas as pd

# %% [markdown]
# **Usuario**
#
# Preencha antes de dar play!

# %%
#@title Preferencia de línguas para o ensino { display-mode: "form" }

def ajuste(x):
  if x == "Selecione":
    return 0
  if x == "Indesejavel" :
    return 1
  if x == "Aceitavel" :
    return 2
  if x == "Preferivel" :
    return 3
  if x == "Muito preverivel" :
    return 4

preflingua = np.zeros((11))

Inglês = 'Aceitavel' #@param ["Selecione", "Indesejavel", "Aceitavel", "Preferivel", "Muito preverivel"]
preflingua[0] = ajuste(Inglês)
Mandarim = 'Muito preverivel' #@param ["Selecione", "Indesejavel", "Aceitavel", "Preferivel", "Muito preverivel"]
preflingua[1] = ajuste(Mandarim)
Russo = 'Indesejavel' #@param ["Selecione", "Indesejavel", "Aceitavel", "Preferivel", "Muito preverivel"]
preflingua[2] = ajuste(Russo)
Alemão = 'Indesejavel' #@param ["Selecione", "Indesejavel", "Aceitavel", "Preferivel", "Muito preverivel"]
preflingua[3] = ajuste(Alemão)
Italiano = 'Indesejavel' #@param ["Selecione", "Indesejavel", "Aceitavel", "Preferivel", "Muito preverivel"]
preflingua[4] = ajuste(Italiano)
Português = 'Indesejavel' #@param ["Selecione", "Indesejavel", "Aceitavel", "Preferivel", "Muito preverivel"]
preflingua[5] = ajuste(Português)
Francês = 'Indesejavel' #@param ["Selecione", "Indesejavel", "Aceitavel", "Preferivel", "Muito preverivel"]
preflingua[6] = ajuste(Francês)
Espanhol = 'Indesejavel' #@param ["Selecione", "Indesejavel", "Aceitavel", "Preferivel", "Muito preverivel"]
preflingua[7] = ajuste(Espanhol)
Sueco = 'Muito preverivel' #@param ["Selecione", "Indesejavel", "Aceitavel", "Preferivel", "Muito preverivel"]
preflingua[8] = ajuste(Sueco)
Dinamarques = 'Indesejavel' #@param ["Selecione", "Indesejavel", "Aceitavel", "Preferivel", "Muito preverivel"]
preflingua[9] = ajuste(Dinamarques)
Japonês = 'Muito preverivel' #@param ["Selecione", "Indesejavel", "Aceitavel", "Preferivel", "Muito preverivel"]
preflingua[10] = ajuste(Japonês)

contador = 0
for i in range (0,11,1):
  if preflingua[i] == 0:
    contador = contador + 1
if contador != 0:
  print("Há", contador, "línguas não classificadas. Por favor, classifique-as.")

# %%
#@title Preferencia de densidade populacional da cidade { display-mode: "form" }

def ajuste2(x):
  if x == "Selecione":
    return 0
  if x == "Ruim" :
    return 1
  if x == "Regular" :
    return 2
  if x == "Bom" :
    return 3
  if x == "Muito bom" :
    return 4

prefcidade = np.zeros((4))

Pequena = 'Ruim' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim"]
prefcidade[0] = ajuste2(Pequena)
Média = 'Ruim' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim"]
prefcidade[1] = ajuste2(Média)
Grande = 'Muito bom' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim"]
prefcidade[2] = ajuste2(Grande)
Enorme = 'Muito bom' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim"]
prefcidade[3] = ajuste2(Enorme)

contador = 0
for i in range (0,4,1):
  if preflingua[i] == 0:
    contador = contador + 1
if contador != 0:
  print("Há", contador, "tamanhos não classificados. Por favor, classifique-os.")

# %%
#@title Preferencia de país { display-mode: "form" }

def ajuste3(x):
  if x == "Selecione":
    return 0
  if x == "Muito ruim" :
    return 1
  if x == "Ruim" :
    return 2
  if x == "Regular" :
    return 3
  if x == "Bom" :
    return 4
  if x == "Muito bom" :
    return 5

prefpais = np.zeros((19))

Alemanha = 'Muito ruim' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
prefpais[0] = ajuste3(Alemanha)
Argentina = 'Muito ruim' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
prefpais[1] = ajuste3(Argentina)
Austrália = 'Ruim' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
prefpais[2] = ajuste3(Austrália)
Áustria = 'Regular' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
prefpais[3] = ajuste3(Áustria)
Canadá = 'Ruim' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
prefpais[4] = ajuste3(Canadá)
Chile = 'Ruim' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
prefpais[5] = ajuste3(Chile)
China = 'Muito bom' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
prefpais[6] = ajuste3(China)
Coreia_do_Sul = 'Muito bom' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
prefpais[7] = ajuste3(Coreia_do_Sul)
Dinamarca = 'Ruim' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
prefpais[8] = ajuste3(Dinamarca)
Espanha = 'Ruim' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
prefpais[9] = ajuste3(Espanha)
Estados_Unidos_da_América = 'Muito ruim' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
prefpais[10] = ajuste3(Estados_Unidos_da_América)
França = 'Muito ruim' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
prefpais[11] = ajuste3(França)
Itália = 'Muito ruim' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
prefpais[12] = ajuste3(Itália)
Japão = 'Muito bom' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
prefpais[13] = ajuste3(Japão)
Portugal = 'Muito ruim' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
prefpais[14] = ajuste3(Portugal)
Rússia = 'Muito ruim' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
prefpais[15] = ajuste3(Rússia)
Suécia = 'Muito bom' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
prefpais[16] = ajuste3(Suécia)
Taiwan = 'Muito bom' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
prefpais[17] = ajuste3(Taiwan)
Uruguai = 'Muito ruim' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
prefpais[18] = ajuste3(Uruguai)

contador = 0
for i in range (0,19,1):
  if prefpais[i] == 0:
    contador = contador + 1
if contador != 0:
  print("Há", contador, "países não classificados. Por favor, classifique-os.")

# %%
#@title Preferencia de duração do intercambio { display-mode: "form" }

def ajuste3(x):
  if x == "Selecione":
    return 0
  if x == "Muito ruim" :
    return 1
  if x == "Ruim" :
    return 2
  if x == "Regular" :
    return 3
  if x == "Bom" :
    return 4
  if x == "Muito bom" :
    return 5

preftempo = np.zeros((6))

duas_semanas = 'Muito bom' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
preftempo[0] = ajuste3(duas_semanas)
quatro_meses = 'Muito bom' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
preftempo[1] = ajuste3(quatro_meses)
um_semestre = 'Muito bom' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
preftempo[2] = ajuste3(um_semestre)
sete_meses = 'Muito bom' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
preftempo[3] = ajuste3(sete_meses)
um_ano = 'Muito bom' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
preftempo[4] = ajuste3(um_ano)
dois_anos = 'Muito bom' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
preftempo[5] = ajuste3(dois_anos)
#vinte_cinco_dias = 'Selecione' #@param ["Selecione", "Muito bom", "Bom", "Regular", "Ruim", "Muito ruim"]
#preftempo[6] = ajuste3(vinte_cinco_dias)

contador = 0
for i in range (0,6,1):
  if preftempo[i] == 0:
    contador = contador + 1
if contador != 0:
  print("Há", contador, "durações não classificadas. Por favor, classifique-as.")

# %%
#@title Informe os pesos dos criterios abaixo (eles serão normalizados pela soma) { display-mode: "form" }

País =  10#@param {type:"number"}

Tamanho_populacional =  10#@param {type:"number"}

Ranking =   10#@param {type:"number"}

Custo_por_mês =   10#@param {type:"number"}

Línguas_ensino =  10#@param {type:"number"}

Duração =  10#@param {type:"number"}

erro = False

if País < 0 or Tamanho_populacional < 0 or Ranking < 0 or Custo_por_mês < 0 or Línguas_ensino < 0 or Duração < 0:
  print("O valor de um peso não pode ser negativo!")
  erro = True

total = País + Tamanho_populacional + Ranking + Custo_por_mês +  + Línguas_ensino + Duração
if total == 0 and erro == False:
  print("Não é possivel obter os pesos com todos os valores zerados")
  erro = True

if erro == False:
  País = País/total
  Tamanho_populacional = Tamanho_populacional/total
  Ranking = Ranking/total
  Custo_por_mês = Custo_por_mês/total
  Línguas_ensino = Línguas_ensino/total
  Duração = Duração/total

  print("Peso para o criterio país: ", País)
  print("Peso para o criterio do tamanho populacional do local: ", Tamanho_populacional)
  print("Peso para o criterio ranking: ", Ranking)
  print("Peso para o criterio custo final por mês, considerando uso da bolsa: ", Custo_por_mês)
  print("Peso para o criterio línguas requeridas: ", Línguas_ensino)
  print("Peso para o criterio de duração: ", Duração)
# Out:
# Peso para o criterio país:  0.16666666666666666
# Peso para o criterio do tamanho populacional do local:  0.16666666666666666
# Peso para o criterio ranking:  0.16666666666666666
# Peso para o criterio custo final por mês, considerando uso da bolsa:  0.16666666666666666
# Peso para o criterio línguas requeridas:  0.16666666666666666
# Peso para o criterio de duração:  0.16666666666666666

# %% [markdown]
# **Processamento**

# %%
#@title Use o play para obter o resultado! { display-mode: "form" }
def conversão(x):
  if x == "Inglês":
    return preflingua[0]
  if x == "Mandarim":
    return preflingua[1]
  if x == "Russo":
    return preflingua[2]
  if x == "Alemão":
    return preflingua[3]
  if x == "Italiano":
    return preflingua[4]
  if x == "Português":
    return preflingua[5]
  if x == "Francês":
    return preflingua[6]
  if x == "Espanhol":
    return preflingua[7]
  if x == "Sueco":
    return preflingua[8]
  if x == "Dinamarques":
    return preflingua[9]
  if x == "Japonês":
    return preflingua[10]

  if x == "Alemanha":
    return prefpais[0]
  if x == "Argentina":
    return prefpais[1]
  if x == "Austrália":
    return prefpais[2]
  if x == "Áustria":
    return prefpais[3]
  if x == "Canadá":
    return prefpais[4]
  if x == "Chile":
    return prefpais[5]
  if x == "China":
    return prefpais[6]
  if x == "Coreia do Sul":
    return prefpais[7]
  if x == "Dinamarca":
    return prefpais[8]
  if x == "Espanha":
    return prefpais[9]
  if x == "EUA":
    return prefpais[10]
  if x == "França":
    return prefpais[11]
  if x == "Itália":
    return prefpais[12]
  if x == "Japão":
    return prefpais[13]
  if x == "Portugal":
    return prefpais[14]
  if x == "Rússia":
    return prefpais[15]
  if x == "Suécia":
    return prefpais[16]
  if x == "Taiwan":
    return prefpais[17]
  if x == "Uruguai":
    return prefpais[18]

  if x == "2 semanas":
    return preftempo[0]
  if x == "4 meses":
    return preftempo[1]
  if x == "1 semestre":
    return preftempo[2]
  if x == "7 meses":
    return preftempo[3]
  if x == "1 ano":
    return preftempo[4]
  if x == "2 anos":
    return preftempo[5]
  
  if x == "-":
    return 0

def conversão2(x):
  if x <= 300000 : #Pequena
    return prefcidade[0]
  if x > 300000 and x <= 1000000: #Média
    return prefcidade[1]
  if x > 1000000 and x <= 2000000: #Grande
    return prefcidade[2]
  if x > 2000000: #Enorme
    return prefcidade[3]

def comparador(i, j, k, maior):
  if maior == False:
    if PROMETHEE[i, k] < PROMETHEE[j, k]:
      return 1
    else:
      return 0
  if maior == True:
    if PROMETHEE[i, k] > PROMETHEE[j, k]:
      return 1
    else:
      return 0

def comparadorcusto(i, j, k, maior, margem):
  if maior == False:
    if abs(int(PROMETHEE[i, k]) - int(PROMETHEE[j, k]))< margem:
      return 0
    else: 
      if PROMETHEE[i, k] < PROMETHEE[j, k]:
        return 1
      else:
        return 0

# Importanto dados da planilha

GoogleSheetsId = '1eg8kcfggUr4Pqvjpejx3YnNzUXAeaInl'
WorksheetName = 'Dados'

URL = 'http://docs.google.com/spreadsheets/d/{0}/gviz/tq?tqx=out:csv&sheet={1}'.format(
    GoogleSheetsId,
    WorksheetName
)

df = pd.read_csv(URL)

# Convertendo tabela em numpy
m = df.to_numpy()
for i in range(0,len(m),1):
  for j in range(0,len(m[0])-1,1):
    if j == 1 or j == 6 or j == 7 or j == 8:
      m[i,j] = conversão(m[i,j])
    if j == 2:
      m[i,j] = conversão2(int(m[i,j]))

u = len(m)
w = len(m[0])-4
PROMETHEE = np.zeros((u,w))
for i in range(0,u,1):
  for j in range(0,w,1):
    if j <= 3:
      PROMETHEE[i,j] = m[i,j+1]
    if j == 4:
      if m[i,j+2] > m[i,j+3]:
        PROMETHEE[i,j] = m[i,j+2]
      else:
        PROMETHEE[i,j] = m[i,j+3]
    if j == 5:
      PROMETHEE[i,j] = m[i,j+3]

#print(PROMETHEE)

# Pesos dos criterios
Pesos = np.array([País,Tamanho_populacional,Ranking,Custo_por_mês,Línguas_ensino,Duração])
X = len(PROMETHEE)

C0 = np.zeros((X,X))
C1 = np.zeros((X,X))
C2 = np.zeros((X,X))
C3 = np.zeros((X,X))
C4 = np.zeros((X,X))
C5 = np.zeros((X,X))

for i in range (0, X, 1):
  for j in range (0, X, 1):
    # Modelo: C'n'[i,j] = comparador(i,j,'n', 'se for ordenamento por maior colocar True, se for por menor colocar False')
    C0[i,j] = comparador(i,j,0, True)
    C1[i,j] = comparador(i,j,1, True) 
    C2[i,j] = comparador(i,j,2, False)  
    C3[i,j] = comparadorcusto(i,j,3, False, 200)
    C4[i,j] = comparador(i,j,4, True)
    C5[i,j] = comparador(i,j,5, True) 
#print(C0)
#print(C1)
#print(C2)
#print(C3)
#print(C4)
#print(C5)

M = np.zeros((X,X)) # Matriz M

for i in range (0,X,1):
  for j in range (0,X,1):
    M[i,j] = C0[i,j]*Pesos[0] + C1[i,j]*Pesos[1] + C2[i,j]*Pesos[2] + C3[i,j]*Pesos[3] + C4[i,j]*Pesos[4] + C5[i,j]*Pesos[5] 
    #continuar o formato C'n'[i,j]*Pesos['n'] até todos os criterios estarem contabilizados

#print(M)

Fluxop = np.zeros(X) #fluxo positivo
Fluxon = np.zeros(X) #fluxo negativo

for i in range(0,X,1):
  for j in range(0,X,1):
    if i != j:
      Fluxop[i] = Fluxop[i] + M[i,j] 
      Fluxon[i] = Fluxon[i] + M[j,i]
  Fluxop[i] = Fluxop[i]/(len(M[0])-1)
  Fluxon[i] = Fluxon[i]/(len(M[0])-1)

#print(Fluxop)
#print(Fluxon)

Fluxo = Fluxop - Fluxon #fluxo resultante
#print(Fluxo)


Ranqueamento = np.zeros((len(Fluxo),2))
for i in range(0,len(Fluxo),1):
  Ranqueamento[i,0] = i
  Ranqueamento[i,1] = Fluxo[i]
  for j in range(0,len(Fluxo),1):
    if Ranqueamento[i,1] < Fluxo[j]:
      Ranqueamento[i,1] = Fluxo[j]
      Ranqueamento[i,0] = j
  Fluxo[int(Ranqueamento[i,0])] = -2
#print(Ranqueamento)

m = df.to_numpy()
for i in range(0,len(m)):
  if m[i,7] == "-":
    m[i,7] = ""
for i in range(0,len(Fluxo),1):
  if i == 0:
    arranjo = np.array([[i+1, m[int(Ranqueamento[i,0]),0], Ranqueamento[i,1], m[int(Ranqueamento[i,0]),1], m[int(Ranqueamento[i,0]),5], m[int(Ranqueamento[i,0]),2], m[int(Ranqueamento[i,0]),3], m[int(Ranqueamento[i,0]),4], m[int(Ranqueamento[i,0]),6], m[int(Ranqueamento[i,0]),7], m[int(Ranqueamento[i,0]),8], m[int(Ranqueamento[i,0]),9], m[int(Ranqueamento[i,0]),10]]])
  else:
    arranjo = np.append(arranjo, [[i+1, m[int(Ranqueamento[i,0]),0], Ranqueamento[i,1], m[int(Ranqueamento[i,0]),1], m[int(Ranqueamento[i,0]),5], m[int(Ranqueamento[i,0]),2], m[int(Ranqueamento[i,0]),3], m[int(Ranqueamento[i,0]),4], m[int(Ranqueamento[i,0]),6], m[int(Ranqueamento[i,0]),7], m[int(Ranqueamento[i,0]),8], m[int(Ranqueamento[i,0]),9], m[int(Ranqueamento[i,0]),10]]], axis=0)

rank = pd.DataFrame(arranjo, columns = ['Posição', 'Nome', 'Fluxo', 'País', 'Cidade', 'N°Habitantes', 'Melhor ranking entre TopUniversities e TimesHigherEducation', 'Custo mensal aproximado em R$', 'Língua de ensino 1', 'Língua de ensino 2', 'Duração', 'Max. créditos de reprovação', 'Edital'])
print(rank.to_string())
# Out:
#    Posição                                                        Nome                  Fluxo           País                  Cidade N°Habitantes Melhor ranking entre TopUniversities e TimesHigherEducation Custo mensal aproximado em R$ Língua de ensino 1 Língua de ensino 2     Duração Max. créditos de reprovação                                                                                                                                              Edital
# 0        1                                   Peking University (“PKU”)    0.48122065727699526          China                  Pequim     21540000                                                          16                          3480           Mandarim                        4 meses                           8                                          http://www.internationaloffice.unicamp.br/wp-content/uploads/2019/02/Edital-012-2019-Peking-University.pdf
# ...

# %% [markdown]
# DÊ PLAY NESSE CÓDIGO PARA VER MELHOR O TOP 10.

# %%
rank.head(11)
# Out:
#    Posição  ...                                             Edital
# 0        1  ...  http://www.internationaloffice.unicamp.br/wp-c...
# 1        2  ...  https://international.umontreal.ca/english/int...
# 2        3  ...  http://www.internationaloffice.unicamp.br/wp-c...
# 3        4  ...  http://www.internationaloffice.unicamp.br/wp-c...
# 4        5  ...  https://slw.univie.ac.at/en/studying/degree-pr...
# 5        6  ...  http://www.internationaloffice.unicamp.br/wp-c...
# 6        7  ...  http://www.internationaloffice.unicamp.br/wp-c...
# 7        8  ...  http://www.internationaloffice.unicamp.br/wp-c...
# 8        9  ...  http://www.internationaloffice.unicamp.br/wp-c...
# 9       10  ...  http://www.internationaloffice.unicamp.br/wp-c...
# 10      11  ...  http://www.internationaloffice.unicamp.br/wp-c...
#
# [11 rows x 13 columns]

# %%
rank.to_excel("AugustoCM.xlsx",sheet_name="AugustoCM",index=False,header=True,na_rep=" ")
